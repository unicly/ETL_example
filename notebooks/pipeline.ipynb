# %% [markdown]
# # Pipeline for publications
#
# The output of the data pipeline should be a JSON file representing a link graph between the different drugs and their respective mentions in the different PubMed publications, the different scientific publications and finally the journals with the date associated with each of these mentions.

# %% [markdown]
# ## Import libraries

# %%
sys.path.append("../")
import src.utils as utils
import src.tasks.extract as extract

import json
import pandas as pd
import sys
import numpy as np

from dotenv import dotenv_values

# %% [markdown]
# ## Read the files into dataframes

# %%
# Read the configuration variables
config = dotenv_values("../.env")

pubmed_csv_df = extract.read_file("../"+config["SOURCE_FILE_PUBMED"])
pubmed_json_df = extract.read_file("../"+config["SOURCE_FILE_JOURNALS"])
trials_df = extract.read_file("../"+config["SOURCE_FILE_TRIALS"])
drugs_df = extract.read_file("../"+config["SOURCE_FILE_DRUGS"])

# %% [markdown]
# ## Check the data

# %%
pubmed_csv_df.head(20)
# Out:
#    id                                              title        date  \
# 0   1  A 44-year-old man with erythema of the face di...  01/01/2019
# 1   2  An evaluation of benadryl, pyribenzamine, and ...  01/01/2019
# 2   3  Diphenhydramine hydrochloride helps symptoms o...  02/01/2019
# 3   4  Tetracycline Resistance Patterns of Lactobacil...  01/01/2020
# 4   5  Appositional Tetracycline bone formation rates...  02/01/2020
# 5   6  Rapid reacquisition of contextual fear followi...  2020-01-01
# 6   7  The High Cost of Epinephrine Autoinjectors and...  01/02/2020
# 7   8  Time to epinephrine treatment is associated wi...  01/03/2020
#
#                                              journal
# 0                       Journal of emergency nursing
# 1                       Journal of emergency nursing
# 2                          The Journal of pediatrics
# 3                         Journal of food protection
# 4            American journal of veterinary research
# 5                                 Psychopharmacology
# 6  The journal of allergy and clinical immunology...
# 7  The journal of allergy and clinical immunology...

# %%
pubmed_json_df.head(20)
# Out:
#    id                                              title       date  \
# 0   9  Gold nanoparticles synthesized from Euphorbia ... 2020-01-01
# 1  10  Clinical implications of umbilical artery Dopp... 2020-01-01
# 2  11  Effects of Topical Application of Betamethason... 2020-01-01
# 3  12  Comparison of pressure release, phonophoresis ... 2020-01-03
# 4      Comparison of pressure BETAMETHASONE release, ... 2020-01-03
#
#                                              journal
# 0  Journal of photochemistry and photobiology. B,...
# 1  The journal of maternal-fetal & neonatal medicine
# 2  Journal of back and musculoskeletal rehabilita...
# 3  Journal of back and musculoskeletal rehabilita...
# 4  The journal of maternal-fetal & neonatal medicine

# %%
trials_df.head(20)
# Out:
#             id                                   scientific_title  \
# 0  NCT01967433  Use of Diphenhydramine as an Adjunctive Sedati...
# 1  NCT04189588  Phase 2 Study IV QUZYTTIR™ (Cetirizine Hydroch...
# 2  NCT04237090
# 3  NCT04237091  Feasibility of a Randomized Controlled Clinica...
# 4  NCT04153396  Preemptive Infiltration With Betamethasone and...
# 5  NCT03490942  Glucagon Infusion in T1D Patients With Recurre...
# 6          NaN  Glucagon Infusion in T1D Patients With Recurre...
# 7  NCT04188184  Tranexamic Acid Versus Epinephrine During Expl...
#
#              date                               journal
# 0  1 January 2020          Journal of emergency nursing
# 1  1 January 2020          Journal of emergency nursing
# 2  1 January 2020          Journal of emergency nursing
# 3  1 January 2020          Journal of emergency nursing
# 4  1 January 2020     Hôpitaux Universitaires de Genève
# 5      25/05/2020                                   NaN
# 6      25/05/2020          Journal of emergency nursing
# 7   27 April 2020  Journal of emergency nursing\xc3\x28

# %%
drugs_df.head()
# Out:
#   atccode             drug
# 0   A04AD  DIPHENHYDRAMINE
# 1   S03AA     TETRACYCLINE
# 2   V03AB          ETHANOL
# 3   A03BA         ATROPINE
# 4   A01AD      EPINEPHRINE

# %% [markdown]
# ## Merge the publications dataframes
#
# Merge dataframe into a single dataframe, for easier handling and manipulation of the data.

# %%
pubmed_csv_df["publication_type"] = "pubmed"
pubmed_json_df["publication_type"] = "pubmed"
pubmed_json_df["date"] = pubmed_json_df["date"].astype(str).str[:10]
trials_df["publication_type"] = "trial"
trials_df.rename(columns = {'scientific_title':'title'}, inplace = True)

all_publications_df = pd.concat([pubmed_csv_df, trials_df, pubmed_json_df], ignore_index=True)
all_publications_df.head()
# Out:
#              id                                              title  \
# 0             1  A 44-year-old man with erythema of the face di...
# 1             2  An evaluation of benadryl, pyribenzamine, and ...
# 2             3  Diphenhydramine hydrochloride helps symptoms o...
# 3             4  Tetracycline Resistance Patterns of Lactobacil...
# 4             5  Appositional Tetracycline bone formation rates...
# 5             6  Rapid reacquisition of contextual fear followi...
# 6             7  The High Cost of Epinephrine Autoinjectors and...
# 7             8  Time to epinephrine treatment is associated wi...
# 8   NCT01967433  Use of Diphenhydramine as an Adjunctive Sedati...
# 9   NCT04189588  Phase 2 Study IV QUZYTTIR™ (Cetirizine Hydroch...
# 10  NCT04237090
# 11  NCT04237091  Feasibility of a Randomized Controlled Clinica...
# 12  NCT04153396  Preemptive Infiltration With Betamethasone and...
# 13  NCT03490942  Glucagon Infusion in T1D Patients With Recurre...
# 14          NaN  Glucagon Infusion in T1D Patients With Recurre...
# 15  NCT04188184  Tranexamic Acid Versus Epinephrine During Expl...
# 16            9  Gold nanoparticles synthesized from Euphorbia ...
# 17           10  Clinical implications of umbilical artery Dopp...
# 18           11  Effects of Topical Application of Betamethason...
# 19           12  Comparison of pressure release, phonophoresis ...
# 20               Comparison of pressure BETAMETHASONE release, ...
#
#               date                                            journal  \
# 0       01/01/2019                       Journal of emergency nursing
# 1       01/01/2019                       Journal of emergency nursing
# 2       02/01/2019                          The Journal of pediatrics
# 3       01/01/2020                         Journal of food protection
# 4       02/01/2020            American journal of veterinary research
# 5       2020-01-01                                 Psychopharmacology
# 6       01/02/2020  The journal of allergy and clinical immunology...
# 7       01/03/2020  The journal of allergy and clinical immunology...
# 8   1 January 2020                       Journal of emergency nursing
# 9   1 January 2020                       Journal of emergency nursing
# 10  1 January 2020                       Journal of emergency nursing
# 11  1 January 2020                       Journal of emergency nursing
# 12  1 January 2020                  Hôpitaux Universitaires de Genève
# 13      25/05/2020                                                NaN
# 14      25/05/2020                       Journal of emergency nursing
# 15   27 April 2020               Journal of emergency nursing\xc3\x28
# 16      2020-01-01  Journal of photochemistry and photobiology. B,...
# 17      2020-01-01  The journal of maternal-fetal & neonatal medicine
# 18      2020-01-01  Journal of back and musculoskeletal rehabilita...
# 19      2020-01-03  Journal of back and musculoskeletal rehabilita...
# 20      2020-01-03  The journal of maternal-fetal & neonatal medicine
#
#    publication_type
# 0            pubmed
# 1            pubmed
# 2            pubmed
# 3            pubmed
# 4            pubmed
# 5            pubmed
# 6            pubmed
# 7            pubmed
# 8             trial
# 9             trial
# 10            trial
# 11            trial
# 12            trial
# 13            trial
# 14            trial
# 15            trial
# 16           pubmed
# 17           pubmed
# 18           pubmed
# 19           pubmed
# 20           pubmed

# %% [markdown]
# ## Clean the data

# %%
import re
def decode_ascii_chars(input: str) -> str:
    cleaned = re.sub(r'[\xc3]', 'APA', input)
    return cleaned

# Replace empty records (only containing one or more space) with NA.
all_publications_df.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# Remove all records that contain NA
all_publications_df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=True)

all_publications_df["journal"] = all_publications_df["journal"].apply(lambda x: utils.remove_ascii_chars(x))
all_publications_df["title"] = all_publications_df["title"].apply(lambda x: utils.remove_ascii_chars(x))

all_publications_df.head()
# Out:
#              id                                              title  \
# 0             1  A 44-year-old man with erythema of the face di...
# 1             2  An evaluation of benadryl, pyribenzamine, and ...
# 2             3  Diphenhydramine hydrochloride helps symptoms o...
# 3             4  Tetracycline Resistance Patterns of Lactobacil...
# 4             5  Appositional Tetracycline bone formation rates...
# 5             6  Rapid reacquisition of contextual fear followi...
# 6             7  The High Cost of Epinephrine Autoinjectors and...
# 7             8  Time to epinephrine treatment is associated wi...
# 8   NCT01967433  Use of Diphenhydramine as an Adjunctive Sedati...
# 9   NCT04189588  Phase 2 Study IV QUZYTTIR™ (Cetirizine Hydroch...
# 11  NCT04237091  Feasibility of a Randomized Controlled Clinica...
# 12  NCT04153396  Preemptive Infiltration With Betamethasone and...
# 15  NCT04188184  Tranexamic Acid Versus Epinephrine During Expl...
# 16            9  Gold nanoparticles synthesized from Euphorbia ...
# 17           10  Clinical implications of umbilical artery Dopp...
# 18           11  Effects of Topical Application of Betamethason...
# 19           12  Comparison of pressure release, phonophoresis ...
#
#               date                                            journal  \
# 0       01/01/2019                       Journal of emergency nursing
# 1       01/01/2019                       Journal of emergency nursing
# 2       02/01/2019                          The Journal of pediatrics
# 3       01/01/2020                         Journal of food protection
# 4       02/01/2020            American journal of veterinary research
# 5       2020-01-01                                 Psychopharmacology
# 6       01/02/2020  The journal of allergy and clinical immunology...
# 7       01/03/2020  The journal of allergy and clinical immunology...
# 8   1 January 2020                       Journal of emergency nursing
# 9   1 January 2020                       Journal of emergency nursing
# 11  1 January 2020                       Journal of emergency nursing
# 12  1 January 2020                  Hôpitaux Universitaires de Genève
# 15   27 April 2020                       Journal of emergency nursing
# 16      2020-01-01  Journal of photochemistry and photobiology. B,...
# 17      2020-01-01  The journal of maternal-fetal & neonatal medicine
# 18      2020-01-01  Journal of back and musculoskeletal rehabilita...
# 19      2020-01-03  Journal of back and musculoskeletal rehabilita...
#
#    publication_type
# 0            pubmed
# 1            pubmed
# 2            pubmed
# 3            pubmed
# 4            pubmed
# 5            pubmed
# 6            pubmed
# 7            pubmed
# 8             trial
# 9             trial
# 11            trial
# 12            trial
# 15            trial
# 16           pubmed
# 17           pubmed
# 18           pubmed
# 19           pubmed

# %%
# Get unique date formats
# This is of course not the best solution to find unique data formats, but works in this case since the dataset is small.
all_publications_df.date.unique()
# Out:
# array(['01/01/2019', '02/01/2019', '01/01/2020', '02/01/2020',
#        '2020-01-01', '01/02/2020', '01/03/2020', '1 January 2020',
#        '27 April 2020', '2020-01-03'], dtype=object)

# %% [markdown]
# ## Clean and normalise the data in the dataframes

# %% [markdown]
# ### Normalise the dates

# %%
all_publications_df["date"] = all_publications_df["date"].apply(utils.convert_date_format)
all_publications_df.reset_index(drop=True, inplace=True)

all_publications_df.head()

# %% [markdown]
# ## Create output data

# %%
output = []
object = {}

for drug in drugs_df["drug"]:  
    if(all_publications_df["title"].str.contains(drug, case = False).any()):
        object = {"Drug": drug}
        publications = all_publications_df[all_publications_df["title"].str.contains(drug, case = False)] # Returnernar en dataframe
        publications = publications[["date", "journal", "title", "publication_type"]]
        publications = publications.to_dict(orient='records')
        object.update({"Publications": publications})
        output.append(object)

json_object = json.dumps(output, indent = 4)

# %% [markdown]
# ## Write to destination

# %%
with open("../"+config["OUTPUT_FILE"], "w+") as outfile:
    outfile.write(json_object)
